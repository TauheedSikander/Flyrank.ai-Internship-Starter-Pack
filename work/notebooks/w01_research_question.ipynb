# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/TauheedSikander/Flyrank.ai-Internship-Starter-Pack/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
## My Lane: Content Refresh Prioritization

## I chose the Content Refresh Prioritization lane because it focuses on helping identify webpages that are most likely to benefit from being updated. Many websites contain thousands of pages, making it difficult for SEO teams to manually decide which pages should be refreshed first. By analyzing historical search performance and content-related signals, this project aims to prioritize pages that deserve attention. I selected this lane because it solves a practical business problem and aligns well with the starter notebooks, where we explored declining pages and content performance.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
#Research Question: Which webpages should be prioritized for content refresh based on their historical performance and content-related signals?

#Decision: This project helps decide which webpages should be refreshed first to improve search performance.

#Who acts on it? The SEO and content team will use the recommendations to decide which pages should be updated before others.

#Unit of Analysis: One webpage.

#Expected Output: A ranked list of webpages that are most likely to benefit from a content refresh.

#Action: The SEO team can review and update the highest-priority pages first instead of manually checking every page.

#Cost of a Wrong Recommendation: If healthy pages are recommended, time and effort may be wasted on unnecessary updates. If declining pages are missed, they may continue losing traffic and search visibility, reducing the effectiveness of the content strategy.

#Why Machine Learning: Large websites can contain thousands of webpages, making manual review difficult and time-consuming. Machine learning can identify patterns in historical data and help prioritize pages more efficiently.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
## Quick Look at the Data

## To understand whether this lane is worth exploring, I examined the starter dataset and collected a few basic statistics. These numbers provide an overview of the data and show that the dataset contains enough information to support a content refresh prioritization project. They also demonstrate that there is a meaningful number of declining pages, making this a practical problem to investigate.

# %%
# !ls
# Out:
# Flyrank.ai-Internship-Starter-Pack  sample_data

# %%
# !ls Flyrank.ai-Internship-Starter-Pack
# Out:
# 02_your_first_readable_model.ipynb  docs       README.md	 submission
# AGENTS.md			    GUIDE.md   requirements.txt  work
# CLAUDE.md			    LICENSE    scripts
# data				    notebooks  SETUP.md
# DATA_USE.md			    outputs    skills

# %%
# !ls data/raw
# Out:
# ls: cannot access 'data/raw': No such file or directory

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
# !ls data
# Out:
# ls: cannot access 'data': No such file or directory

# %%
# !ls /content
# Out:
# Flyrank.ai-Internship-Starter-Pack  sample_data

# %%
# %cd /content/Flyrank.ai-Internship-Starter-Pack
# !find . -name "*.csv"
# Out:
# /content/Flyrank.ai-Internship-Starter-Pack
# ./data/raw/content_refresh_anonymized.csv
# ./outputs/refresh_queue_sample.csv

# %%
# %cd /content/Flyrank.ai-Internship-Starter-Pack
# Out:
# /content/Flyrank.ai-Internship-Starter-Pack

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total Pages:", len(df))
print("Declining Pages:", (df["trend_direction"] == "down").sum())
print("Average CTR:", round(df["ctr"].mean(), 4))
# Out:
# Total Pages: 30000
# Declining Pages: 16262
# Average CTR: 0.5107

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
## Careful Words

## This project is intended to provide decision support by identifying patterns in historical website data. The findings will be based on observed, measured, and directional relationships rather than absolute facts. The recommendations are meant to help SEO teams prioritize webpages for review and improvement.

## This project cannot prove cause-and-effect relationships, predict Google's search algorithm, or guarantee future search rankings. Any recommendations should be used alongside human judgment and SEO expertise.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
